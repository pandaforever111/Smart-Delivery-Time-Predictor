# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikranth3140/ML-Project/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

# Load the dataset
# df = pd.read_csv("../Datasets/new/train.csv")
df = pd.read_csv("../content/train.csv")

# Separate features and target variable
X = df.drop(columns=["Time_taken(min)"])
y = df["Time_taken(min)"]

# Encode categorical features
categorical_columns = X.select_dtypes(include=["object"]).columns
label_encoder = LabelEncoder()

for col in categorical_columns:
    X[col] = label_encoder.fit_transform(X[col])

# Normalize numerical features for SVM (important for optimal performance)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train an SVM model
svm_model = SVR(kernel="rbf")  # Using RBF kernel for regression
svm_model.fit(X_train, y_train)

# Make predictions on the validation set
y_pred = svm_model.predict(X_val)

# Evaluate the model
mse = mean_squared_error(y_val, y_pred)
r2 = r2_score(y_val, y_pred)
accuracy = 1 - mse / y_val.var()  # Approximation of accuracy for regression

print(f"Mean Squared Error: {mse:.2f}")
print(f"R² Score: {r2:.2f}")
print(f"Accuracy: {accuracy:.2%}")
# Out:
# Mean Squared Error: 34.47
# R² Score: 0.61
# Accuracy: 60.73%

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

# Load the dataset
# df = pd.read_csv("../Datasets/new/train.csv")
df = pd.read_csv("../content/kbest_features.csv")

# Separate features and target variable
X = df.drop(columns=["Time_taken(min)"])
y = df["Time_taken(min)"]

# Encode categorical features
categorical_columns = X.select_dtypes(include=["object"]).columns
label_encoder = LabelEncoder()

for col in categorical_columns:
    X[col] = label_encoder.fit_transform(X[col])

# Normalize numerical features for SVM (important for optimal performance)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Train an SVM model
svm_model = SVR(kernel="rbf")  # Using RBF kernel for regression
svm_model.fit(X_train, y_train)

# Make predictions on the validation set
y_pred = svm_model.predict(X_val)

# Evaluate the model
mse = mean_squared_error(y_val, y_pred)
r2 = r2_score(y_val, y_pred)
accuracy = 1 - mse / y_val.var()  # Approximation of accuracy for regression

print(f"Mean Squared Error: {mse:.2f}")
print(f"R² Score: {r2:.2f}")
print(f"Accuracy: {accuracy:.2%}")
# Out:
# Mean Squared Error: 34.08
# R² Score: 0.61
# Accuracy: 61.17%

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

# Load the dataset
df = pd.read_csv("../content/train.csv")

# Separate features and target variable
X = df.drop(columns=["Time_taken(min)"])
y = df["Time_taken(min)"]

# Encode categorical features
categorical_columns = X.select_dtypes(include=["object"]).columns
label_encoder = LabelEncoder()

for col in categorical_columns:
    X[col] = label_encoder.fit_transform(X[col])

# Normalize numerical features for SVM (important for optimal performance)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split the dataset into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Define the parameter grid for GridSearchCV
param_grid = {
    'C': [0.1, 1, 10, 100],            # Regularization parameter
    'gamma': ['scale', 'auto', 0.01, 0.1, 1],  # Kernel coefficient
    'epsilon': [0.1, 0.2, 0.5, 1]     # Epsilon in the loss function
}

# Initialize GridSearchCV with SVR and cross-validation
grid_search = GridSearchCV(SVR(kernel="rbf"), param_grid, scoring='neg_mean_squared_error', cv=3, verbose=2)
grid_search.fit(X_train, y_train)

# Best hyperparameters from GridSearch
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Train the model with the best parameters
best_svm_model = grid_search.best_estimator_

# Make predictions on the validation set
y_pred = best_svm_model.predict(X_val)

# Evaluate the model
mse = mean_squared_error(y_val, y_pred)
r2 = r2_score(y_val, y_pred)
accuracy = 1 - mse / y_val.var()  # Approximation of accuracy for regression

print(f"Mean Squared Error: {mse:.2f}")
print(f"R² Score: {r2:.2f}")
print(f"Accuracy: {accuracy:.2%}")
# Out:
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# [CV] END ....................C=0.1, epsilon=0.1, gamma=scale; total time=  45.0s
# [CV] END ....................C=0.1, epsilon=0.1, gamma
# [CV] END .......................C=10, epsilon=0.1, gamma=0.1; total time= 1.9min
# [CV] END .......................C=10, epsilon=0.1, gamma=0.1; total time= 1.8min
# [CV] END .......................C=10, epsilon=0.1, gamma=0.1; total time= 1.8min
# [CV] END .........................C=10, epsilon=0.1, gamma=1; total time= 2.3min
# [CV] END .........................C=10, epsilon=0.1, gamma=1; total time= 2.2min
# [CV] END .........................C=10, epsilon=0.1, gamma=1; total time= 2.2min
# [CV] END .....................C=10, epsilon=0.2, gamma=scale; total time=  53.0s
# [CV] END .....................C=10, epsilon=0.2, gamma=scale; total time=  52.9s
# [CV] END .....................C=10, epsilon=0.2, gamma=scale; total time=  53.1s
# [CV] END ......................C=10, epsilon=0.2, gamma=auto; total time=  54.4s
# [CV] END ......................C=10, epsilon=0.2, gamma=auto; total time=  52.7s
# [CV] END ......................C=10, epsilon=0.2, gamma=auto; total time=  52.8s
# [CV] END ......................C=10, epsilon=0.2, gamma=0.01; total time=  43.5s
# [CV] END ......................C=10, epsilon=0.2, gamma=0.01; total time=  43.4s
# [CV] END ......................C=10, epsilon=0.2, gamma=0.01; total time=  44.9s
# [CV] END .......................C=10, epsilon=0.2, gamma=0.1; total time= 1.8min
# [CV] END .......................C=10, epsilon=0.2, gamma=0.1; total time= 1.8min
# [CV] END .......................C=10, epsilon=0.2, gamma=0.1; total time= 1.9min
# [CV] END .........................C=10, epsilon=0.2, gamma=1; total time= 2.2min
# [CV] END .........................C=10, epsilon=0.2, gamma=1; total time= 2.2min
# [CV] END .........................C=10, epsilon=0.2, gamma=1; total time= 2.2min
# [CV] END .....................C=10, epsilon=0.5, gamma=scale; total time=  49.8s
# [CV] END .....................C=10, epsilon=0.5, gamma=scale; total time=  51.2s
# [CV] END .....................C=10, epsilon=0.5, gamma=scale; total time=  50.6s
# [CV] END ......................C=10, epsilon=0.5, gamma=auto; total time=  50.6s
# [CV] END ......................C=10, epsilon=0.5, gamma=auto; total time=  50.3s
# [CV] END ......................C=10, epsilon=0.5, gamma=auto; total time=  50.3s
# [CV] END ......................C=10, epsilon=0.5, gamma=0.01; total time=  43.3s
# [CV] END ......................C=10, epsilon=0.5, gamma=0.01; total time=  41.7s
# [CV] END ......................C=10, epsilon=0.5, gamma=0.01; total time=  41.9s
# [CV] END .......................C=10, epsilon=0.5, gamma=0.1; total time= 1.8min
# [CV] END .......................C=10, epsilon=0.5, gamma=0.1; total time= 1.8min
# [CV] END .......................C=10, epsilon=0.5, gamma=0.1; total time= 1.8min
# [CV] END .........................C=10, epsilon=0.5, gamma=1; total time= 2.2min
# [CV] END .........................C=10, epsilon=0.5, gamma=1; total time= 2.1min
# [CV] END .........................C=10, epsilon=0.5, gamma=1; total time= 2.2min
# [CV] END .......................C=10, epsilon=1, gamma=scale; total time=  45.6s
# [CV] END .......................C=10, epsilon=1, gamma=scale; total time=  46.8s
# [CV] END .......................C=10, epsilon=1, gamma=scale; total time=  45.5s
# [CV] END ........................C=10, epsilon=1, gamma=auto; total time=  46.9s
# [CV] END ........................C=10, epsilon=1, gamma=auto; total time=  46.7s
# [CV] END ........................C=10, epsilon=1, gamma=auto; total time=  47.0s
# [CV] END ........................C=10, epsilon=1, gamma=0.01; total time=  39.0s
# [CV] END ........................C=10, epsilon=1, gamma=0.01; total time=  39.0s
